# %% [markdown]
# # ISYS2407 Information Systems Solutions & Design
#
# # Assignment 3
#
# # Data Cleaning
#
# #### Student name: Rajbeer Kohli
#
# #### Student number: s3798453

# %% [markdown]
# ## 1. Import libraries

# %%
# Pandas is the main library used for exploratory data analysis
# Numpy allows fast advanced mathematical operations on large amount of data
import numpy as np
import pandas as pd

# Library for saving a python object to file
import joblib 

# Library to assign missing values
from sklearn.impute import SimpleImputer

# Matplotlib is the main plotting library for python
import matplotlib.pyplot as plt

# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ## 2. Load data

# %%
# Loading the data
attrition_df= pd.read_csv("employee-attrition.csv")

# %%
# What is the data type?
#type(diabetes_df)
print(type(attrition_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
attrition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1470 non-null   int64
#  1   business_travel             1470 non-null   object
#  2   daily_rate                  1470 non-null   int64
#  3   department                  1470 non-null   object
#  4   distance_from_home          1470 non-null   int64
#  5   education                   1470 non-null   int64
#  6   education_field             1470 non-null   object
#  7   employee_count              1470 non-null   int64
#  8   employee_number             1470 non-null   int64
#  9   environment_satisfaction    1470 non-null   int64
#  10  gender                      1470 non-null   object
#  11  hourly_rate                 1470 non-null   int64
#  12  job_involvement             1470 non-null   int64
# ...

# %%
# shape will return as tuple containing the number of rows and columns
print(attrition_df.shape)
print(attrition_df.shape[0])
print(attrition_df.shape[1])
# Out:
# (1470, 35)
# 1470
# 35

# %%
attrition_df.head(10)
# Out:
#    age    business_travel  daily_rate              department  \
# 0   41      Travel_Rarely        1102                   Sales
# 1   49  Travel_Frequently         279  Research & Development
# 2   37      Travel_Rarely        1373  Research & Development
# 3   33  Travel_Frequently        1392  Research & Development
# 4   27      Travel_Rarely         591  Research & Development
# 5   32  Travel_Frequently        1005  Research & Development
# 6   59      Travel_Rarely        1324  Research & Development
# 7   30      Travel_Rarely        1358  Research & Development
# 8   38  Travel_Frequently         216  Research & Development
# 9   36      Travel_Rarely        1299  Research & Development
#
#    distance_from_home  education education_field  employee_count  \
# 0                   1          2   Life Sciences               1
# 1                   8          1   Life Sciences               1
# 2                   2          2           Other               1
# ...

# %% [markdown]
# # 3. Fix data types (if required)

# %%
attrition_df.dtypes
# Out:
# age                            int64
# business_travel               object
# daily_rate                     int64
# department                    object
# distance_from_home             int64
# education                      int64
# education_field               object
# employee_count                 int64
# employee_number                int64
# environment_satisfaction       int64
# gender                        object
# hourly_rate                    int64
# job_involvement                int64
# job_level                      int64
# job_role                      object
# job_satisfaction               int64
# marital_status                object
# monthly_income                 int64
# monthly_rate                   int64
# num_companies_worked           int64
# over_18_yrs                   object
# overtime                      object
# percent_salary_hike            int64
# performance_rating             int64
# relationship_satisfaction      int64
# ...

# %% [markdown]
# # 4. Delete duplicate rows (if any)

# %%
# Dropping rows with duplicate values
print(attrition_df.shape)

attrition_df.drop_duplicates(inplace=True) # Keeping first copy

attrition_df.reset_index(drop=True, inplace=True) # Resetting index to default integer index

# Check
print(attrition_df.shape)
# Out:
# (1470, 35)
# (1470, 35)

# %% [markdown]
# # 5. Handle Missing Values

# %% [markdown]
# ## 5.1 Percentage of missing values encoded as NaN

# %%
# Count of missing values in the whole dataframe by column

attrition_df.isnull().sum()
# Out:
# age                           0
# business_travel               0
# daily_rate                    0
# department                    0
# distance_from_home            0
# education                     0
# education_field               0
# employee_count                0
# employee_number               0
# environment_satisfaction      0
# gender                        0
# hourly_rate                   0
# job_involvement               0
# job_level                     0
# job_role                      0
# job_satisfaction              0
# marital_status                0
# monthly_income                0
# monthly_rate                  0
# num_companies_worked          0
# over_18_yrs                   0
# overtime                      0
# percent_salary_hike           0
# performance_rating            0
# relationship_satisfaction     0
# standard_hours                0
# stock_option_level            0
# total_working_years           0
# training_times_last_year      0
# ...

# %%
# Display percentage of missing values (NaN) per column

percent_missing = round(attrition_df.isna().mean() * 100, 4)
print(percent_missing)
# Out:
# age                           0.0
# business_travel               0.0
# daily_rate                    0.0
# department                    0.0
# distance_from_home            0.0
# education                     0.0
# education_field               0.0
# employee_count                0.0
# employee_number               0.0
# environment_satisfaction      0.0
# gender                        0.0
# hourly_rate                   0.0
# job_involvement               0.0
# job_level                     0.0
# job_role                      0.0
# job_satisfaction              0.0
# marital_status                0.0
# monthly_income                0.0
# monthly_rate                  0.0
# num_companies_worked          0.0
# over_18_yrs                   0.0
# overtime                      0.0
# percent_salary_hike           0.0
# performance_rating            0.0
# relationship_satisfaction     0.0
# standard_hours                0.0
# stock_option_level            0.0
# ...

# %% [markdown]
# ## 5.2 What if missing values are not encoded as NaN?

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['total_working_years'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 23     21      Travel_Rarely         391  Research & Development
# 127    19      Travel_Rarely         528                   Sales
# 296    18      Travel_Rarely         230  Research & Development
# 301    18      Travel_Rarely         812                   Sales
# 457    18  Travel_Frequently        1306                   Sales
# 615    27         Non-Travel         443  Research & Development
# 727    18         Non-Travel         287  Research & Development
# 828    18         Non-Travel         247  Research & Development
# 972    18         Non-Travel        1124  Research & Development
# 1153   18  Travel_Frequently         544                   Sales
# 1311   18         Non-Travel        1431  Research & Development
#
#       distance_from_home  education education_field  employee_count  \
# 23                    15          2   Life Sciences               1
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['stock_option_level'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 0      41      Travel_Rarely        1102                   Sales
# 2      37      Travel_Rarely        1373  Research & Development
# 3      33  Travel_Frequently        1392  Research & Development
# 5      32  Travel_Frequently        1005  Research & Development
# 8      38  Travel_Frequently         216  Research & Development
# ...   ...                ...         ...                     ...
# 1460   29      Travel_Rarely         468  Research & Development
# 1463   31         Non-Travel         325  Research & Development
# 1464   26      Travel_Rarely        1167                   Sales
# 1468   49  Travel_Frequently        1023                   Sales
# 1469   34      Travel_Rarely         628  Research & Development
#
#       distance_from_home  education education_field  employee_count  \
# 0                      1          2   Life Sciences               1
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['years_at_company'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 2      37      Travel_Rarely        1373  Research & Development
# 23     21      Travel_Rarely         391  Research & Development
# 77     45      Travel_Rarely         193  Research & Development
# 86     23      Travel_Rarely         541                   Sales
# 109    22      Travel_Rarely         534  Research & Development
# 127    19      Travel_Rarely         528                   Sales
# 171    19  Travel_Frequently         602                   Sales
# 264    28      Travel_Rarely         529  Research & Development
# 265    29      Travel_Rarely        1210                   Sales
# 296    18      Travel_Rarely         230  Research & Development
# 301    18      Travel_Rarely         812                   Sales
# 347    47  Travel_Frequently        1309                   Sales
# 352    48      Travel_Rarely         530                   Sales
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['years_in_current_role'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 2      37      Travel_Rarely        1373  Research & Development
# 6      59      Travel_Rarely        1324  Research & Development
# 7      30      Travel_Rarely        1358  Research & Development
# 17     22         Non-Travel        1123  Research & Development
# 23     21      Travel_Rarely         391  Research & Development
# ...   ...                ...         ...                     ...
# 1411   25      Travel_Rarely         309         Human Resources
# 1427   40      Travel_Rarely         543  Research & Development
# 1437   39         Non-Travel         105  Research & Development
# 1438   23  Travel_Frequently         638                   Sales
# 1450   35      Travel_Rarely        1146         Human Resources
#
#       distance_from_home  education  education_field  employee_count  \
# 2                      2          2            Other               1
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['years_since_last_promotion'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 0      41      Travel_Rarely        1102                   Sales
# 2      37      Travel_Rarely        1373  Research & Development
# 6      59      Travel_Rarely        1324  Research & Development
# 7      30      Travel_Rarely        1358  Research & Development
# 10     35      Travel_Rarely         809  Research & Development
# ...   ...                ...         ...                     ...
# 1460   29      Travel_Rarely         468  Research & Development
# 1464   26      Travel_Rarely        1167                   Sales
# 1465   36  Travel_Frequently         884  Research & Development
# 1467   27      Travel_Rarely         155  Research & Development
# 1468   49  Travel_Frequently        1023                   Sales
#
#       distance_from_home  education education_field  employee_count  \
# 0                      1          2   Life Sciences               1
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['stock_option_level'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 0      41      Travel_Rarely        1102                   Sales
# 2      37      Travel_Rarely        1373  Research & Development
# 3      33  Travel_Frequently        1392  Research & Development
# 5      32  Travel_Frequently        1005  Research & Development
# 8      38  Travel_Frequently         216  Research & Development
# ...   ...                ...         ...                     ...
# 1460   29      Travel_Rarely         468  Research & Development
# 1463   31         Non-Travel         325  Research & Development
# 1464   26      Travel_Rarely        1167                   Sales
# 1468   49  Travel_Frequently        1023                   Sales
# 1469   34      Travel_Rarely         628  Research & Development
#
#       distance_from_home  education education_field  employee_count  \
# 0                      1          2   Life Sciences               1
# ...

# %%
# There are lots of zero values in some of the columns
attrition_df[(attrition_df['years_with_curr_manager'] == 0)]
# Out:
#       age    business_travel  daily_rate              department  \
# 2      37      Travel_Rarely        1373  Research & Development
# 3      33  Travel_Frequently        1392  Research & Development
# 6      59      Travel_Rarely        1324  Research & Development
# 7      30      Travel_Rarely        1358  Research & Development
# 17     22         Non-Travel        1123  Research & Development
# ...   ...                ...         ...                     ...
# 1434   52         Non-Travel         585                   Sales
# 1438   23  Travel_Frequently         638                   Sales
# 1453   36      Travel_Rarely        1120                   Sales
# 1461   50      Travel_Rarely         410                   Sales
# 1464   26      Travel_Rarely        1167                   Sales
#
#       distance_from_home  education education_field  employee_count  \
# 2                      2          2           Other               1
# ...

# %% [markdown]
# ## Check for missing values

# %%
# Checking for missing values
sns.heatmap(attrition_df.isnull(),cbar=False,yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Dataset has no missing values.
# - If there were any, that would have been noticed in figure represented by different colour shade on purple background.

# %% [markdown]
# # 6 Handle outliers

# %% [markdown]
# ## 6.1 Visualise outliers

# %%
# Example 1 - age 

sns.boxplot(x=attrition_df["age"]) # if used y=x=attrition["age"] - plot displayed vertically
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Example 2 - number of stock_option_level

sns.boxplot(x=attrition_df["stock_option_level"])
# Out:
# <AxesSubplot:xlabel='stock_option_level'>

# %%
# Example 3 - subplots

fig, ax = plt.subplots(2,4, figsize=(16,6))  # 2 rows and 4 columns

# Row 0
ax1 = sns.boxplot(y=attrition_df["daily_rate"], ax=ax[0,0]) # row 0, col 0
ax2 = sns.boxplot(y=attrition_df["years_with_curr_manager"], ax=ax[0,1]) 
ax3 = sns.boxplot(y=attrition_df["job_involvement"], ax=ax[0,2])
ax4 = sns.boxplot(y=attrition_df["monthly_rate"], ax=ax[0,3])

# Row 1
ax5 = sns.boxplot(y=attrition_df["stock_option_level"], ax=ax[1,0])
ax6 = sns.boxplot(y=attrition_df["training_times_last_year"], ax=ax[1,1])
ax7 = sns.boxplot(y=attrition_df["work_life_balance"], ax=ax[1,2])
ax8 = sns.boxplot(y=attrition_df["age"], ax=ax[1,3])

# %% [markdown]
# ## 6.2 Percentage of outliers

# %%
# Finding the percentages of outlier per columns

columns = ['age', 
               'daily_rate', 
               'distance_from_home', 
               'education', 
               'employee_count', 
               'employee_number',
               'environment_satisfaction',             
               'hourly_rate',
               'job_involvement',
               'job_level',           
               'job_satisfaction',        
               'monthly_income',
               'monthly_rate',
               'num_companies_worked',
               'percent_salary_hike',
               'performance_rating',
               'relationship_satisfaction',
               'standard_hours',
               'stock_option_level',
               'total_working_years',
               'training_times_last_year',
               'work_life_balance',
               'years_at_company',
               'years_in_current_role',
               'years_since_last_promotion',
               'years_with_curr_manager']
print(columns)
print()

for col in columns:
    percentile_25 = attrition_df[col].quantile(0.25)
    percentile_75 = attrition_df[col].quantile(0.75)
    iqr = percentile_75 - percentile_25 # Inter Quartile Range
    total = len(attrition_df[col])
    #total = attrition_df[col].shape[0] # also works

    # Determining the upper and lower boundaries for outliers
    # The lower and upper boundaries are less than the bottom whisker or greater than the top whisker
    #cut_off = iqr * 3    # three times IQR - for detecting extreme outliers
    cut_off = iqr * 1.5  # normally use 1.5 times IQR
    lower, upper = percentile_25 - cut_off, percentile_75 + cut_off
    print(f"col: {col}, lower: {lower}, upper: {upper}")

    # Count all values that are less than the lower boundary OR those that are greater than the upper boundary
    #num_attrition = attrition_df[(attrition_df[col] < lower) | (attrition_df[col] > upper)].count() # returns a list of things
    num_attrition = len(attrition_df[(attrition_df[col] < lower) | (attrition_df[col] > upper)])
    
    pc_attrition = round(num_attrition*100/total,2)
    
    print(f"Num attrition: {num_attrition}, total rows: {total}, percent: {pc_attrition}")
    print()
# Out:
# ['age', 'daily_rate', 'distance_from_home', 'education', 'employee_count', 'employee_number', 'environment_satisfaction', 'hourly_rate', 'job_involvement', 'job_level', 'job_satisfaction', 'monthly_income', 'monthly_rate', 'num_companies_worked', 'percent_salary_hike', 'performance_rating', 'relationship_satisfaction', 'standard_hours', 'stock_option_level', 'total_working_years', 'training_times_last_year', 'work_life_balance', 'years_at_company', 'years_in_current_role', 'years_since_last_promotion', 'years_with_curr_manager']
#
# col: age, lower: 10.5, upper: 62.5
# Num attrition: 0, total rows: 1470, percent: 0.0
#
# col: daily_rate, lower: -573.0, upper: 2195.0
# Num attrition: 0, total rows: 1470, percent: 0.0
#
# col: distance_from_home, lower: -16.0, upper: 32.0
# Num attrition: 0, total rows: 1470, percent: 0.0
#
# col: education, lower: -1.0, upper: 7.0
# Num attrition: 0, total rows: 1470, percent: 0.0
#
# col: employee_count, lower: 1.0, upper: 1.0
# ...

# %% [markdown]
# ## 6.3 Replace outliers with median

# %%
# Using Inter Quartile Range (IQR) to detect outliers - for non-normal (non-Gaussian) distributions
columns = ['age', 
               'daily_rate', 
               'distance_from_home', 
               'education', 
               'employee_count', 
               'employee_number',
               'environment_satisfaction',             
               'hourly_rate',
               'job_involvement',
               'job_level',           
               'job_satisfaction',        
               'monthly_income',
               'monthly_rate',
               'num_companies_worked',
               'percent_salary_hike',
               'performance_rating',
               'relationship_satisfaction',
               'standard_hours',
               'stock_option_level',
               'total_working_years',
               'training_times_last_year',
               'work_life_balance',
               'years_at_company',
               'years_in_current_role',
               'years_since_last_promotion',
               'years_with_curr_manager']

for col in columns:
    median_val = attrition_df[col].quantile(0.50)
    percentile_25 = attrition_df[col].quantile(0.25)
    percentile_75 = attrition_df[col].quantile(0.75)
    iqr = percentile_75 - percentile_25 # Inter Quartile Range
    
    # Determine the upper and lower boundaries for outliers
    # The lower and upper boundaries are less than the bottom whisker or greater than the top whisker
    #cut_off = iqr * 3    # three times IQR - for detecting extreme outliers
    cut_off = iqr * 1.5  # normally use 1.5 times IQR
    lower, upper = percentile_25 - cut_off, percentile_75 + cut_off
    print(f"col: {col}, lower: {lower}, upper: {upper},  median_val: {median_val}")
    
    # Replace all outliers in column with median value
    # Replace all values that are less than the lower boundary OR those that are greater than the upper boundary
    attrition_df[col] = np.where((attrition_df[col] < lower) | (attrition_df[col] > upper), median_val, attrition_df[col])

attrition_df.describe().T  # T means transpose - will transpose rows to column
# Out:
# col: age, lower: 10.5, upper: 62.5,  median_val: 36.0
# col: daily_rate, lower: -573.0, upper: 2195.0,  median_val: 802.0
# col: distance_from_home, lower: -16.0, upper: 32.0,  median_val: 7.0
# col: education, lower: -1.0, upper: 7.0,  median_val: 3.0
# col: employee_count, lower: 1.0, upper: 1.0,  median_val: 1.0
# col: employee_number, lower: -1105.5, upper: 3152.5,  median_val: 1020.5
# col: environment_satisfaction, lower: -1.0, upper: 7.0,  median_val: 3.0
# col: hourly_rate, lower: -5.625, upper: 137.375,  median_val: 66.0
# col: job_involvement, lower: 0.5, upper: 4.5,  median_val: 3.0
# col: job_level, lower: -2.0, upper: 6.0,  median_val: 2.0
# col: job_satisfaction, lower: -1.0, upper: 7.0,  median_val: 3.0
# col: monthly_income, lower: -5291.0, upper: 16581.0,  median_val: 4919.0
# col: monthly_rate, lower: -10574.75, upper: 39083.25,  median_val: 14235.5
# col: num_companies_worked, lower: -3.5, upper: 8.5,  median_val: 2.0
# ...

# %% [markdown]
# # 7 View the cleaned data

# %%
# Final check of the data
attrition_df.head()
# Out:
#     age    business_travel  daily_rate              department  \
# 0  41.0      Travel_Rarely      1102.0                   Sales
# 1  49.0  Travel_Frequently       279.0  Research & Development
# 2  37.0      Travel_Rarely      1373.0  Research & Development
# 3  33.0  Travel_Frequently      1392.0  Research & Development
# 4  27.0      Travel_Rarely       591.0  Research & Development
#
#    distance_from_home  education education_field  employee_count  \
# 0                 1.0        2.0   Life Sciences             1.0
# 1                 8.0        1.0   Life Sciences             1.0
# 2                 2.0        2.0           Other             1.0
# 3                 3.0        4.0   Life Sciences             1.0
# 4                 2.0        1.0         Medical             1.0
#
#    employee_number  environment_satisfaction  gender  hourly_rate  \
# 0              1.0                       2.0  Female         94.0
# ...

# %% [markdown]
# # 8 Pickle the cleaned data
#
# ### For use later in another Jupyter Notebook for Machine Learning

# %%
# Saving the object as a pickle in a file 
joblib.dump(attrition_df, 'attrition-cleaned.pkl')
# Out:
# ['attrition-cleaned.pkl']
